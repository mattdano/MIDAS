# %% [markdown]
# # Check the outputs of the python and reference implementation

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
cpp_ver = pd.read_csv('../pymidas/og_output.txt',names=['score'])
py_ver = pd.read_csv('../pymidas/py_output_test.txt',names=['score'])

# %%
(cpp_ver-py_ver).sum()
# Out:
# score    2.759072e+09
# dtype: float64

# %%
import numpy as np

# %%
cpp_ver.score.plot()

# %%
py_ver.plot()

# %%
(abs(cpp_ver-py_ver)/cpp_ver.max()).plot()

# %%
input_tweets = pd.read_csv('./tweet_processed_small.csv',names=['src','dest','time'])

# %%
input_tweets.time.plot()

# %%
py_ver[py_ver.score == py_ver.score.max()]
# Out:
#              score
# 1108  57936.062267

# %%
cpp_ver
# Out:
#            score
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 4970  814.000000
# 4971  406.000614
# 4972  814.000000
# 4973  814.000000
# 4974  406.000614
# 4975  202.002764
# 4976  814.000000
# 4977  406.000614
# 4978  406.000614
# 4979  814.000000
# 4980  814.000000
# 4981  406.000614
# 4982  406.000614
# 4983  406.000614
# 4984  406.000614
# 4985  406.000614
# 4986  814.000000
# 4987  814.000000
# 4988  814.000000
# 4989  406.000614
# ...
